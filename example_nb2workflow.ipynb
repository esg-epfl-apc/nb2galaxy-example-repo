# %%
import numpy as np
import matplotlib.pyplot as pt

# %%
min_ = -100
max_ = 100
power = 3

# %%
x = np.linspace(min_, max_, 1001)
pt.figure(figsize=(5, 4))
im = pt.plot(x, x ** power)
pt.xlabel("x")
pt.ylabel(f"$y^{power}$")
# Out:
# Text(0, 0.5, '$y^3$')
